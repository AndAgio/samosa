# %%
from memorization import Memorization

# %%
mem = Memorization()

# %%
print(mem.full_list())
# Out:
# [0.06980802792321117, 0.0, 0.13259668508287292, 0.5171232876712328, 0.0, 0.8860862489829129, 0.05920519059205187, 0.01726973684210531, 0.18261633011413525, 0.09744013212221303, 0.0, 0.3011844331641286, 0.0, 0.535986452159187, 0.0, 0.5570247933884298, 0.00622222222222224, 0.28387650085763294, 0.02019315188762072, 0.0, 0.9965397923875432, 0.5172697368421053, 0.44314381270903014, 0.0796311818943839, 0.6077943615257049, 0.029641185647425905, 0.8443357783211084, 0.0, 0.44818652849740936, 0.07285828662930349, 0.0, 0.0008176614881438837, 0.05240549828178698, 0.14775510204081632, 0.024431339511373218, 0.10551948051948057, 0.5393081761006289, 0.6385642737896494, 0.0034364261168384758, 0.0, 0.5978705978705978, 0.09083119108826054, 0.0, 0.00428449014567267, 0.0, 0.0, 0.09823677581863977, 0.030431107354184306, 1.0, 0.2627324171382377, 0.2717569786535303, 0.570300157977883, 0.038785834738617186, 0.0033167495854062867, 0.0, 0.828548644338118, 0.638047138047138, 0.0, 0.7333333333333334, 0.936300174
# ...

# %%
print(mem.full_prob())
# Out:
# [5.073050016685785e-06, 0.0, 9.635992241638522e-06, 3.7580094742611654e-05, 0.0, 6.439316499719038e-05, 4.3025265439568035e-06, 1.2550166704518959e-06, 1.3270991948829646e-05, 7.081114860202159e-06, 0.0, 2.188750691209179e-05, 0.0, 3.895090809699585e-05, 0.0, 4.0479794680662885e-05, 4.5217785815392757e-07, 2.0629714522184304e-05, 1.467465455880201e-06, 0.0, 7.241998321397534e-05, 3.7590737414963826e-05, 3.2203899656507234e-05, 5.786912775739536e-06, 4.416929238097388e-05, 2.1540676884422054e-06, 6.135909811135185e-05, 0.0, 3.257036108186821e-05, 5.294716713771958e-06, 0.0, 5.9420638993476424e-08, 3.808383102088023e-06, 1.0737576252663934e-05, 1.7754606597992356e-06, 7.668252754523625e-06, 3.919230256404903e-05, 4.640538625968552e-05, 2.4973003948118077e-07, 0.0, 4.344811817116087e-05, 6.600833588548872e-06, 0.0, 3.113600749315508e-07, 0.0, 0.0, 7.139008105974634e-06, 2.2114724375358087e-06, 7.267144148902386e-05, 1.9093143479331252e-05, 1.9748971373453937e-05, 4.144453456167079e-05, 
# ...

# %%
print(mem.get([0,1,2,3,4,5]))
# Out:
# [0.06980803 0.         0.13259669 0.51712329 0.         0.88608625]

# %%
print(mem.get_prob([0,1,2,3,4,5]))
# Out:
# [5.07305002e-06 0.00000000e+00 9.63599224e-06 3.75800947e-05
#  0.00000000e+00 6.43931650e-05]

# %%
mem.plot_scores_hist()
# Out:
# Plot saved as all_mem_scores_hist.png

# %%
mem.plot_scores_hist(list(range(10)))
# Out:
# Plot saved as mem_scores_hist.png

# %%
mem.plot_scores_kde()
# Out:
# Plot saved as all_mem_scores_distribution.png

# %%
mem.plot_scores_kde(list(range(10)))
# Out:
# Plot saved as mem_scores_distribution.png

# %%
mem.plot_prob_dist()
# Out:
# Plot saved as all_prob_dist.png

# %%
mem.plot_prob_dist(plot='line')
# Out:
# Plot saved as all_prob_dist.png

# %%
mem.plot_prob_dist(list(range(1000)))
# Out:
# Plot saved as prob_dist.png

# %%
mem.plot_prob_dist(list(range(1000)), plot='line')
# Out:
# Plot saved as prob_dist.png
